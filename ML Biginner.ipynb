# %% [markdown]
# # ML Biginner Project

# %%
import pandas as pd
df = pd.read_csv("film_data.csv")
df
# Out:
#     Age  Gender Favorite_Film_Category
# 0    25    Male                 Action
# 1    32  Female                 Comedy
# 2    48    Male               Thriller
# 3    19  Female              Animation
# 4    65    Male                  Drama
# ..  ...     ...                    ...
# 93   84  Female                Romance
# 94   75    Male                 Action
# 95   79  Female               Musical
# 96   85    Male                 Comedy
# 97   87  Female                  Drama
#
# [98 rows x 3 columns]
