# %% [markdown]
# # ML Biginner Project

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.shape #get deimentsion of data frame
# Out:
# (198, 60)

# %%
df.describe()
# Out:
#                No    R_SHTCNT  R_SHTCYCTM  R_SHTDRYTM  R_SHTPHTIM  R_SHTSTSPT  \
# count  198.000000  198.000000  198.000000  198.000000  198.000000       198.0
# mean    99.500000   82.742424   36.083838    7.722020    3.421566       187.0
# std     57.301832   54.556814    3.400140    0.627836    0.009016         0.0
# min      1.000000    1.000000   35.090000    5.760000    3.390000       187.0
# 25%     50.250000   30.250000   35.170000    7.392500    3.420000       187.0
# 50%     99.500000   79.500000   35.210000    7.940000    3.420000       187.0
# 75%    148.750000  130.750000   35.632500    8.177500    3.430000       187.0
# max    198.000000  180.000000   69.750000   10.330000    3.440000       187.0
#
#        R_SHTPRSPT  R_SHTCSNVOL  R_SHTMAXPRS  R_SHTKPPRS  ...  R_SHTHTR29TMP  \
# count  198.000000   198.000000   198.000000  198.000000  ...     198.000000
# mean    30.961616    13.352020   108.717172   77.404545  ...     230.679293
# ...

# %%
df.values
# Out:
# array([[1, 'Good', '1/16/2017 8:48', ..., nan, nan, nan],
#        [2, 'Good', '1/16/2017 8:49', ..., nan, nan, nan],
#        [3, 'Good', '1/16/2017 8:49', ..., nan, nan, nan],
#        ...,
#        [196, 'Good', '1/16/2017 21:34', ..., nan, nan, nan],
#        [197, 'Good', '1/16/2017 21:34', ..., nan, nan, nan],
#        [198, 'Good', '1/16/2017 21:35', ..., nan, nan, nan]], dtype=object)
